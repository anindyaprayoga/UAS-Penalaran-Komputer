# %%
# === SETUP
# !apt install poppler-utils -y > /dev/null
# !pip install requests beautifulsoup4 lxml > /dev/null

import os, re, time
import requests
from bs4 import BeautifulSoup
from pathlib import Path
from urllib.request import urlretrieve
from google.colab import drive
import subprocess

# === MOUNT DRIVE
drive.mount('/content/drive')

# === PATH
BASE_DIR = "/content/drive/MyDrive/cbr_banking"
PDF_DIR  = f"{BASE_DIR}/data/pdf"
RAW_DIR  = f"{BASE_DIR}/data/raw"
LOG_DIR  = f"{BASE_DIR}/logs"
LOG_FILE = f"{LOG_DIR}/cleaning.log"

Path(PDF_DIR).mkdir(parents=True, exist_ok=True)
Path(RAW_DIR).mkdir(parents=True, exist_ok=True)
Path(LOG_DIR).mkdir(parents=True, exist_ok=True)

# === UTILITAS
def open_page(url):
    for _ in range(3):
        try:
            return BeautifulSoup(requests.get(url, timeout=15).text, "lxml")
        except:
            time.sleep(3)
    return None

def get_pdf_link(soup):
    try:
        tag = soup.find("a", href=re.compile("/direktori/download_file/.+/pdf/"))
        href = tag["href"]
        if href.startswith("http"):
            return href
        return "https://putusan3.mahkamahagung.go.id" + href
    except:
        return None

def clean_text(text):
    original_len = len(text)

    # Hapus bagian disclaimer panjang di akhir
    text = re.sub(r"Disclaimer[\s\S]+?kepaniteraan@mahkamahagung.go.id.*", "", text, flags=re.IGNORECASE)

    # Buang direktori, halaman, nomor hal
    text = re.sub(r'direktori putusan', '', text, flags=re.IGNORECASE)
    text = re.sub(r'hal\.?\s*\d+\s*dari\s*\d+\s*hal\.?', '', text, flags=re.IGNORECASE)
    text = re.sub(r'halaman\s+\d+', '', text, flags=re.IGNORECASE)

    # Normalisasi karakter
    text = text.replace("\xa0", " ")           # spasi aneh
    text = re.sub(r'\n{2,}', '\n', text)        # newline dobel
    text = text.strip()

    # Jangan buang karakter kecuali betul-betul mengganggu
    # Biarkan huruf kapital, simbol hukum, tanda baca tetap

    return text, original_len, len(text)


import shutil

def extract_text_pdftotext(pdf_path):
    temp_pdf = "/content/temp.pdf"
    temp_txt = "/content/temp.txt"

    import shutil
    shutil.copy(pdf_path, temp_pdf)

    # ✅ Pakai -layout agar struktur tidak hilang
    subprocess.run(["pdftotext", "-layout", "-enc", "UTF-8", temp_pdf, temp_txt], check=True)

    with open(temp_txt, "r", encoding="utf-8") as f:
        return f.read()



# === TAHAP 1: SCRAPE & DOWNLOAD PDF
def download_pdf_only(pdf_url, case_num):
    try:
        pdf_path = f"/content/case_{case_num:03d}.pdf"  # hanya sementara
        urlretrieve(pdf_url, pdf_path)

        size = os.path.getsize(pdf_path)
        if size < 5000:
            raise Exception(f"PDF terlalu kecil ({size} bytes)")

        print(f"✅ Downloaded: case_{case_num:03d}.pdf ({size} bytes)")
        return pdf_path  # return path

    except Exception as e:
        print(f"❌ Gagal download case_{case_num:03d}: {e}")
        return None


def scrape_pdf_and_extract(max_cases=35):
    total = 0
    base = "https://putusan3.mahkamahagung.go.id/search.html?jenis_doc=putusan&cat=5b3b183b41bc6ab3764cab235b9a3f8a&court=8bb6198cd9528aaac4199a1d5627bbb9"

    for page in range(1, 20):
        url = base if page == 1 else f"{base}&page={page}"
        print(f"📄 Halaman {page}")
        soup = open_page(url)
        if not soup:
            continue

        links = soup.find_all("a", href=re.compile("/direktori/putusan/"))
        for a in links:
            detail_url = a["href"]
            if not detail_url.startswith("http"):
                detail_url = "https://putusan3.mahkamahagung.go.id" + detail_url

            detail_soup = open_page(detail_url)
            if not detail_soup:
                continue

            pdf_link = get_pdf_link(detail_soup)
            if not pdf_link:
                continue

            case_txt = f"{RAW_DIR}/case_{total+1:03d}.txt"
            if os.path.exists(case_txt):
                continue

            temp_pdf_path = download_pdf_only(pdf_link, total + 1)
            if not temp_pdf_path:
                continue

            try:
                raw_text = extract_text_pdftotext(temp_pdf_path)
                cleaned, before, after = clean_text(raw_text)

                with open(case_txt, "w", encoding="utf-8") as f:
                    f.write(cleaned)

                with open(LOG_FILE, "a", encoding="utf-8") as log:
                    log.write(f"case_{total+1:03d}.txt | {before} chars -> {after} chars\n")

                print(f"✅ Ekstrak: case_{total+1:03d}.pdf ({before} → {after})")
                total += 1
            except Exception as e:
                print(f"❌ Gagal ekstrak case_{total+1:03d}: {e}")

            if total >= max_cases:
                print(f"\n🎉 Selesai ekstrak total {total} file")
                return


# === TAHAP 2: EKSTRAKSI PDF KE TXT
def extract_all_pdf_to_txt():
    pdf_files = sorted([f for f in os.listdir(PDF_DIR) if f.endswith(".pdf")])
    for file in pdf_files:
        pdf_path = os.path.join(PDF_DIR, file)
        txt_path = os.path.join(RAW_DIR, file.replace(".pdf", ".txt"))
        if os.path.exists(txt_path):
            continue
        try:
            raw_text = extract_text_pdftotext(pdf_path)
            cleaned, before, after = clean_text(raw_text)
            with open(txt_path, "w", encoding="utf-8") as f:
                f.write(cleaned)
            with open(LOG_FILE, "a", encoding="utf-8") as log:
                log.write(f"{file.replace('.pdf','.txt')} | {before} chars -> {after} chars\n")
            print(f"✅ Ekstrak: {file} ({before} → {after})")
        except Exception as e:
            print(f"❌ Gagal ekstrak {file}: {e}")


scrape_pdf_and_extract(max_cases=150)
extract_all_pdf_to_txt()
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.
#
# Mounted at /content/drive
# 📄 Halaman 1
# ✅ Downloaded: case_001.pdf (104859 bytes)
# ✅ Ekstrak: case_001.pdf (79387 → 69378)
# ✅ Downloaded: case_002.pdf (633628 bytes)
# ✅ Ekstrak: case_002.pdf (1433111 → 1266110)
# ✅ Downloaded: case_003.pdf (358019 bytes)
# ✅ Ekstrak: case_003.pdf (239700 → 209684)
# ✅ Downloaded: case_004.pdf (121641 bytes)
# ✅ Ekstrak: case_004.pdf (211006 → 183512)
# ✅ Downloaded: case_005.pdf (98252 bytes)
# ✅ Ekstrak: case_005.pdf (164538 → 143148)
# ✅ Downloaded: case_006.pdf (213932 bytes)
# ✅ Ekstrak: case_006.pdf (350256 → 305271)
# ✅ Downloaded: case_007.pdf (511786 bytes)
# ✅ Ekstrak: case_007.pdf (572578 → 504306)
# ✅ Downloaded: case_008.pdf (457734 bytes)
# ✅ Ekstrak: case_008.pdf (658273 → 578133)
# ✅ Downloaded: case_009.pdf (55748 bytes)
# ✅ Ekstrak: case_009.pdf (77769 → 67687)
# ✅ Downloaded: case_010.pdf (285324 bytes)
# ✅ Ekstrak: case_010.pdf (449529 → 391653)
# ✅ Downloaded: case_011.pdf (344321 bytes)
# ✅ Ekstrak: case_011.pdf (572278 → 504233)
# ✅ Downloaded: case_012.pdf (304969 bytes)
# ✅ Ekstrak: case_012.pdf (441368 → 383473)
# ✅ Downloaded: case_013.pdf (168459 bytes)
# ✅ Ekstrak: case_013.pdf (159791 → 139618)
# ✅ Downloaded: case_014.pdf (104588 bytes)
# ✅ Ekstrak: case_014.pdf (76942 → 66934)
# ✅ Downloaded: case_015.pdf (208647 bytes)
# ✅ Ekstrak: case_015.pdf (361836 → 318860)
# ✅ Downloaded: case_016.pdf (102191 bytes)
# ✅ Ekstrak: case_016.pdf (69345 → 60595)
# ✅ Downloaded: case_017.pdf (473200 bytes)
# ✅ Ekstrak: case_017.pdf (149017 → 130305)
# ✅ Downloaded: case_018.pdf (284887 bytes)
# ✅ Ekstrak: case_018.pdf (332297 → 291033)
# ✅ Downloaded: case_019.pdf (136180 bytes)
# ✅ Ekstrak: case_019.pdf (132747 → 115285)
# ✅ Downloaded: case_020.pdf (133406 bytes)
# ✅ Ekstrak: case_020.pdf (113893 → 98905)
# ✅ Downloaded: case_021.pdf (283025 bytes)
# ✅ Ekstrak: case_021.pdf (124043 → 107810)
# 📄 Halaman 2
# ✅ Downloaded: case_022.pdf (413528 bytes)
# ✅ Ekstrak: case_022.pdf (506251 → 444419)
# ✅ Downloaded: case_023.pdf (473200 bytes)
# ✅ Ekstrak: case_023.pdf (149017 → 130305)
# ✅ Downloaded: case_024.pdf (284887 bytes)
# ✅ Ekstrak: case_024.pdf (332297 → 291033)
# ✅ Downloaded: case_025.pdf (102191 bytes)
# ✅ Ekstrak: case_025.pdf (69345 → 60595)
# ✅ Downloaded: case_026.pdf (208647 bytes)
# ✅ Ekstrak: case_026.pdf (361836 → 318860)
# ✅ Downloaded: case_027.pdf (120449 bytes)
# ✅ Ekstrak: case_027.pdf (118435 → 103428)
# ✅ Downloaded: case_028.pdf (227210 bytes)
# ✅ Ekstrak: case_028.pdf (339653 → 300490)
# ✅ Downloaded: case_029.pdf (270762 bytes)
# ✅ Ekstrak: case_029.pdf (167504 → 147333)
# ✅ Downloaded: case_030.pdf (70995 bytes)
# ✅ Ekstrak: case_030.pdf (110599 → 96839)
# ✅ Downloaded: case_031.pdf (109289 bytes)
# ✅ Ekstrak: case_031.pdf (79120 → 69044)
# ✅ Downloaded: case_032.pdf (120703 bytes)
# ✅ Ekstrak: case_032.pdf (127720 → 111322)
# ✅ Downloaded: case_033.pdf (190290 bytes)
# ✅ Ekstrak: case_033.pdf (186714 → 163975)
# ✅ Downloaded: case_034.pdf (70531 bytes)
# ✅ Ekstrak: case_034.pdf (113644 → 99746)
# ✅ Downloaded: case_035.pdf (1821454 bytes)
# ✅ Ekstrak: case_035.pdf (138326 → 120680)
# ✅ Downloaded: case_036.pdf (133124 bytes)
# ✅ Ekstrak: case_036.pdf (84372 → 73114)
# ✅ Downloaded: case_037.pdf (136180 bytes)
# ✅ Ekstrak: case_037.pdf (132747 → 115285)
# ✅ Downloaded: case_038.pdf (133406 bytes)
# ✅ Ekstrak: case_038.pdf (113893 → 98905)
# ✅ Downloaded: case_039.pdf (283025 bytes)
# ✅ Ekstrak: case_039.pdf (124043 → 107810)
# 📄 Halaman 3
# ✅ Downloaded: case_040.pdf (857923 bytes)
# ✅ Ekstrak: case_040.pdf (1027438 → 904911)
# ✅ Downloaded: case_041.pdf (193209 bytes)
# ✅ Ekstrak: case_041.pdf (229741 → 201866)
# ✅ Downloaded: case_042.pdf (147816 bytes)
# ✅ Ekstrak: case_042.pdf (151327 → 131339)
# ✅ Downloaded: case_043.pdf (125894 bytes)
# ✅ Ekstrak: case_043.pdf (113074 → 97991)
# ✅ Downloaded: case_044.pdf (184815 bytes)
# ✅ Ekstrak: case_044.pdf (237153 → 207002)
# ✅ Downloaded: case_045.pdf (146058 bytes)
# ✅ Ekstrak: case_045.pdf (199704 → 174458)
# ✅ Downloaded: case_046.pdf (217738 bytes)
# ✅ Ekstrak: case_046.pdf (287821 → 253587)
# ✅ Downloaded: case_047.pdf (105720 bytes)
# ✅ Ekstrak: case_047.pdf (81205 → 71122)
# ✅ Downloaded: case_048.pdf (426161 bytes)
# ✅ Ekstrak: case_048.pdf (942348 → 828972)
# ✅ Downloaded: case_049.pdf (311317 bytes)
# ✅ Ekstrak: case_049.pdf (575283 → 503988)
# ✅ Downloaded: case_050.pdf (119375 bytes)
# ✅ Ekstrak: case_050.pdf (98098 → 85585)
# ✅ Downloaded: case_051.pdf (131311 bytes)
# ✅ Ekstrak: case_051.pdf (166555 → 145123)
# ✅ Downloaded: case_052.pdf (669008 bytes)
# ✅ Ekstrak: case_052.pdf (245261 → 216466)
# ✅ Downloaded: case_053.pdf (298028 bytes)
# ✅ Ekstrak: case_053.pdf (549377 → 483806)
# ✅ Downloaded: case_054.pdf (141984 bytes)
# ✅ Ekstrak: case_054.pdf (89090 → 77829)
# ✅ Downloaded: case_055.pdf (136180 bytes)
# ✅ Ekstrak: case_055.pdf (132747 → 115285)
# ✅ Downloaded: case_056.pdf (133406 bytes)
# ✅ Ekstrak: case_056.pdf (113893 → 98905)
# ✅ Downloaded: case_057.pdf (283025 bytes)
# ✅ Ekstrak: case_057.pdf (124043 → 107810)
# 📄 Halaman 4
# ✅ Downloaded: case_058.pdf (141984 bytes)
# ✅ Ekstrak: case_058.pdf (89090 → 77829)
# ✅ Downloaded: case_059.pdf (298028 bytes)
# ✅ Ekstrak: case_059.pdf (549377 → 483806)
# ✅ Downloaded: case_060.pdf (299607 bytes)
# ✅ Ekstrak: case_060.pdf (531165 → 468115)
# ✅ Downloaded: case_061.pdf (123273 bytes)
# ✅ Ekstrak: case_061.pdf (131636 → 114004)
# ✅ Downloaded: case_062.pdf (78437 bytes)
# ✅ Ekstrak: case_062.pdf (110908 → 97003)
# ✅ Downloaded: case_063.pdf (791340 bytes)
# ✅ Ekstrak: case_063.pdf (1415930 → 1247135)
# ✅ Downloaded: case_064.pdf (1536608 bytes)
# ✅ Ekstrak: case_064.pdf (3337241 → 2986300)
# ✅ Downloaded: case_065.pdf (346931 bytes)
# ✅ Ekstrak: case_065.pdf (320004 → 279667)
# ✅ Downloaded: case_066.pdf (196326 bytes)
# ✅ Ekstrak: case_066.pdf (153791 → 133616)
# ✅ Downloaded: case_067.pdf (140084 bytes)
# ✅ Ekstrak: case_067.pdf (105501 → 91654)
# ✅ Downloaded: case_068.pdf (178018 bytes)
# ✅ Ekstrak: case_068.pdf (270952 → 236937)
# ✅ Downloaded: case_069.pdf (787693 bytes)
# ✅ Ekstrak: case_069.pdf (1251423 → 1134063)
# ✅ Downloaded: case_070.pdf (136180 bytes)
# ✅ Ekstrak: case_070.pdf (132747 → 115285)
# ✅ Downloaded: case_071.pdf (133406 bytes)
# ✅ Ekstrak: case_071.pdf (113893 → 98905)
# ✅ Downloaded: case_072.pdf (283025 bytes)
# ✅ Ekstrak: case_072.pdf (124043 → 107810)
# 📄 Halaman 5
# ✅ Downloaded: case_073.pdf (60560 bytes)
# ✅ Ekstrak: case_073.pdf (77449 → 67391)
# ✅ Downloaded: case_074.pdf (142945 bytes)
# ✅ Ekstrak: case_074.pdf (146792 → 127894)
# ✅ Downloaded: case_075.pdf (223391 bytes)
# ✅ Ekstrak: case_075.pdf (268203 → 234205)
# ✅ Downloaded: case_076.pdf (103287 bytes)
# ✅ Ekstrak: case_076.pdf (64109 → 55387)
# ✅ Downloaded: case_077.pdf (123524 bytes)
# ✅ Ekstrak: case_077.pdf (118261 → 103129)
# ✅ Downloaded: case_078.pdf (787693 bytes)
# ✅ Ekstrak: case_078.pdf (1251423 → 1134063)
# ✅ Downloaded: case_079.pdf (114121 bytes)
# ✅ Ekstrak: case_079.pdf (107290 → 93490)
# ✅ Downloaded: case_080.pdf (202738 bytes)
# ✅ Ekstrak: case_080.pdf (368608 → 324483)
# ✅ Downloaded: case_081.pdf (214736 bytes)
# ✅ Ekstrak: case_081.pdf (378713 → 333331)
# ✅ Downloaded: case_082.pdf (68794 bytes)
# ✅ Ekstrak: case_082.pdf (79611 → 69538)
# ✅ Downloaded: case_083.pdf (126299 bytes)
# ✅ Ekstrak: case_083.pdf (106471 → 92629)
# ✅ Downloaded: case_084.pdf (235757 bytes)
# ✅ Ekstrak: case_084.pdf (417831 → 368628)
# ✅ Downloaded: case_085.pdf (158142 bytes)
# ✅ Ekstrak: case_085.pdf (126848 → 110595)
# ✅ Downloaded: case_086.pdf (166340 bytes)
# ✅ Ekstrak: case_086.pdf (300066 → 264736)
# ✅ Downloaded: case_087.pdf (1776652 bytes)
# ✅ Ekstrak: case_087.pdf (2374047 → 2130450)
# ✅ Downloaded: case_088.pdf (98495 bytes)
# ✅ Ekstrak: case_088.pdf (85739 → 74376)
# ✅ Downloaded: case_089.pdf (309255 bytes)
# ✅ Ekstrak: case_089.pdf (517810 → 462330)
# ✅ Downloaded: case_090.pdf (1304060 bytes)
# ✅ Ekstrak: case_090.pdf (1721408 → 1519973)
# ✅ Downloaded: case_091.pdf (120374 bytes)
# ✅ Ekstrak: case_091.pdf (107247 → 94635)
# ✅ Downloaded: case_092.pdf (136180 bytes)
# ✅ Ekstrak: case_092.pdf (132747 → 115285)
# ✅ Downloaded: case_093.pdf (133406 bytes)
# ✅ Ekstrak: case_093.pdf (113893 → 98905)
# ✅ Downloaded: case_094.pdf (283025 bytes)
# ✅ Ekstrak: case_094.pdf (124043 → 107810)
# 📄 Halaman 6
# ✅ Downloaded: case_095.pdf (98495 bytes)
# ✅ Ekstrak: case_095.pdf (85739 → 74376)
# ✅ Downloaded: case_096.pdf (1304060 bytes)
# ✅ Ekstrak: case_096.pdf (1721408 → 1519973)
# ✅ Downloaded: case_097.pdf (309255 bytes)
# ✅ Ekstrak: case_097.pdf (517810 → 462330)
# ✅ Downloaded: case_098.pdf (213709 bytes)
# ✅ Ekstrak: case_098.pdf (488437 → 427110)
# ✅ Downloaded: case_099.pdf (138827 bytes)
# ✅ Ekstrak: case_099.pdf (164132 → 142891)
# ✅ Downloaded: case_100.pdf (72246 bytes)
# ✅ Ekstrak: case_100.pdf (104928 → 92313)
# ✅ Downloaded: case_101.pdf (121341 bytes)
# ✅ Ekstrak: case_101.pdf (148159 → 129435)
# ✅ Downloaded: case_102.pdf (169280 bytes)
# ✅ Ekstrak: case_102.pdf (145827 → 127066)
# ✅ Downloaded: case_103.pdf (189199 bytes)
# ✅ Ekstrak: case_103.pdf (338809 → 298395)
# ✅ Downloaded: case_104.pdf (123115 bytes)
# ✅ Ekstrak: case_104.pdf (194598 → 169602)
# ✅ Downloaded: case_105.pdf (127505 bytes)
# ✅ Ekstrak: case_105.pdf (136674 → 119026)
# ✅ Downloaded: case_106.pdf (191004 bytes)
# ✅ Ekstrak: case_106.pdf (208402 → 183396)
# ✅ Downloaded: case_107.pdf (251728 bytes)
# ✅ Ekstrak: case_107.pdf (492174 → 432002)
# ✅ Downloaded: case_108.pdf (1526355 bytes)
# ✅ Ekstrak: case_108.pdf (119441 → 104492)
# ✅ Downloaded: case_109.pdf (136180 bytes)
# ✅ Ekstrak: case_109.pdf (132747 → 115285)
# ✅ Downloaded: case_110.pdf (133406 bytes)
# ✅ Ekstrak: case_110.pdf (113893 → 98905)
# ✅ Downloaded: case_111.pdf (283025 bytes)
# ✅ Ekstrak: case_111.pdf (124043 → 107810)
# 📄 Halaman 7
# ✅ Downloaded: case_112.pdf (484700 bytes)
# ✅ Ekstrak: case_112.pdf (1175110 → 1041123)
# ✅ Downloaded: case_113.pdf (199925 bytes)
# ✅ Ekstrak: case_113.pdf (343312 → 304138)
# ✅ Downloaded: case_114.pdf (139339 bytes)
# ✅ Ekstrak: case_114.pdf (255146 → 222419)
# ✅ Downloaded: case_115.pdf (111686 bytes)
# ✅ Ekstrak: case_115.pdf (118814 → 103683)
# ✅ Downloaded: case_116.pdf (522130 bytes)
# ✅ Ekstrak: case_116.pdf (1486535 → 1313321)
# ✅ Downloaded: case_117.pdf (56920813 bytes)
# ✅ Ekstrak: case_117.pdf (811268 → 641749)
# ✅ Downloaded: case_118.pdf (114116 bytes)
# ✅ Ekstrak: case_118.pdf (67105 → 58338)
# ✅ Downloaded: case_119.pdf (142651 bytes)
# ✅ Ekstrak: case_119.pdf (230467 → 202677)
# ✅ Downloaded: case_120.pdf (582515 bytes)
# ✅ Ekstrak: case_120.pdf (662533 → 587765)
# ✅ Downloaded: case_121.pdf (1043455 bytes)
# ✅ Ekstrak: case_121.pdf (2366660 → 2076824)
# ✅ Downloaded: case_122.pdf (431380 bytes)
# ✅ Ekstrak: case_122.pdf (810188 → 716636)
# ✅ Downloaded: case_123.pdf (576812 bytes)
# ✅ Ekstrak: case_123.pdf (711585 → 629529)
# ✅ Downloaded: case_124.pdf (200991 bytes)
# ✅ Ekstrak: case_124.pdf (166623 → 145233)
# ✅ Downloaded: case_125.pdf (143911 bytes)
# ✅ Ekstrak: case_125.pdf (176166 → 153701)
# ✅ Downloaded: case_126.pdf (188408 bytes)
# ✅ Ekstrak: case_126.pdf (79135 → 69052)
# ✅ Downloaded: case_127.pdf (136180 bytes)
# ✅ Ekstrak: case_127.pdf (132747 → 115285)
# ✅ Downloaded: case_128.pdf (133406 bytes)
# ✅ Ekstrak: case_128.pdf (113893 → 98905)
# ✅ Downloaded: case_129.pdf (283025 bytes)
# ✅ Ekstrak: case_129.pdf (124043 → 107810)
# 📄 Halaman 8
# ✅ Downloaded: case_130.pdf (89208 bytes)
# ✅ Ekstrak: case_130.pdf (159623 → 139466)
# ✅ Downloaded: case_131.pdf (435908 bytes)
# ✅ Ekstrak: case_131.pdf (626552 → 552170)
# ✅ Downloaded: case_132.pdf (154309 bytes)
# ✅ Ekstrak: case_132.pdf (316808 → 276489)
# ✅ Downloaded: case_133.pdf (140272 bytes)
# ✅ Ekstrak: case_133.pdf (90552 → 79236)
# ✅ Downloaded: case_134.pdf (143911 bytes)
# ✅ Ekstrak: case_134.pdf (176166 → 153701)
# ✅ Downloaded: case_135.pdf (188408 bytes)
# ✅ Ekstrak: case_135.pdf (79135 → 69052)
# ✅ Downloaded: case_136.pdf (185709 bytes)
# ✅ Ekstrak: case_136.pdf (108369 → 94618)
# ✅ Downloaded: case_137.pdf (171069 bytes)
# ✅ Ekstrak: case_137.pdf (311206 → 274581)
# ✅ Downloaded: case_138.pdf (204584 bytes)
# ✅ Ekstrak: case_138.pdf (358621 → 316547)
# ✅ Downloaded: case_139.pdf (149418 bytes)
# ✅ Ekstrak: case_139.pdf (166319 → 144906)
# ✅ Downloaded: case_140.pdf (126801 bytes)
# ✅ Ekstrak: case_140.pdf (106409 → 92581)
# ✅ Downloaded: case_141.pdf (136180 bytes)
# ✅ Ekstrak: case_141.pdf (132747 → 115285)
# ✅ Downloaded: case_142.pdf (133406 bytes)
# ✅ Ekstrak: case_142.pdf (113893 → 98905)
# ✅ Downloaded: case_143.pdf (283025 bytes)
# ✅ Ekstrak: case_143.pdf (124043 → 107810)
# 📄 Halaman 9
# ✅ Downloaded: case_144.pdf (136180 bytes)
# ✅ Ekstrak: case_144.pdf (132747 → 115285)
# ✅ Downloaded: case_145.pdf (133406 bytes)
# ✅ Ekstrak: case_145.pdf (113893 → 98905)
# ✅ Downloaded: case_146.pdf (283025 bytes)
# ✅ Ekstrak: case_146.pdf (124043 → 107810)
# 📄 Halaman 10
# ✅ Downloaded: case_147.pdf (136180 bytes)
# ✅ Ekstrak: case_147.pdf (132747 → 115285)
# ✅ Downloaded: case_148.pdf (133406 bytes)
# ✅ Ekstrak: case_148.pdf (113893 → 98905)
# ✅ Downloaded: case_149.pdf (283025 bytes)
# ✅ Ekstrak: case_149.pdf (124043 → 107810)
# 📄 Halaman 11
# ✅ Downloaded: case_150.pdf (136180 bytes)
# ✅ Ekstrak: case_150.pdf (132747 → 115285)
#
# 🎉 Selesai ekstrak total 150 file
